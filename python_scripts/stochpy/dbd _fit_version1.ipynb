# %%
#!pip install PySCeS
#!pip install stochpy

# %%
import stochpy

# %%
def doSequentialSim(smod,n_generations,cell_division_times):    
    for i in range(1,n_generations):     
        ### divide each species between two daughter cells ###        
        for j in range(0,len(smod.data_stochsim.species_labels)): 
            species_amount = smod.SSA.sim_output[-2][1:][j]     
            if species_amount:
                smod.settings.X_matrix[j] = np.random.binomial(n=species_amount
                                                               ,p=0.5,size=1)                
        ### replace last time point with species amounts after division ###
        species_after_division = copy.deepcopy(list(smod.settings.X_matrix))
        species_after_division.insert(0,cell_division_times[0:i].sum())
        species_after_division.append(np.NAN) # no reaction occurred at cell division
        smod.SSA.sim_output[-1] = copy.deepcopy(species_after_division)                         
        ### Set settings for new simulation and simulate the next generation ### 
        smod.settings.starttime = copy.deepcopy(smod.SSA.sim_output[-1][0])
        smod.settings.endtime = smod.settings.starttime + cell_division_times[i]
        smod.SSA.Execute(smod.settings,False) # do stochastic simulation     
    smod.FillDataStochsim() # add all data to data_stochsim object

# %%
import stochpy, numpy as np,copy,os,matplotlib.gridspec as gridspec
import matplotlib as plt
plt.rcParams.update({'figure.max_open_warning': 0})
smod = stochpy.SSA(model_file='DBD.psc',dir='E:\HXG\igem2020upp\stochastic model\DBD Py')
T_GENERATION = 600
# Out:
# Adding \n to input file

# %%
### 2: Do long simulation for probability density function of protein copy numbers ###
N_GENERATIONS = 200
CELL_DIVISION_TIMES = abs(np.random.gamma(T_GENERATION,1,size=N_GENERATIONS)) 
smod.DoStochSim(end=CELL_DIVISION_TIMES[0],mode='time',trajectories=10)
doSequentialSim(smod,N_GENERATIONS,CELL_DIVISION_TIMES)
smod.PlotSpeciesTimeSeries(species2plot=['dimer'])
smod.PlotSpeciesTimeSeries(species2plot=['dimeractive'])
smod.PlotSpeciesTimeSeries(species2plot=['dimerpromoter'])
smod.PlotSpeciesTimeSeries(species2plot=['mRNA'])
smod.PlotSpeciesTimeSeries(species2plot=['Protein'])
smod.PlotSpeciesTimeSeries(species2plot=['MatureProtein'])

# %%
### 1: Do short looping simulations for a time series plot ###
kd = [1,2.5,5]
k2 = [1,10,50]
k3 = [0.1,0.5,1]
for i in kd:
  for j in k2:
    for k in k3:
      print('simulation with kd, k2, k3 =',i,', ',j,', ',k)
      graphtitle = str('simulation with kd,2,3 ='+str(i)+' '+str(j)+' '+str(k))
      smod.ChangeParameter('kd',i)
      smod.ChangeParameter('k2',j)
      smod.ChangeParameter('k3',k)
      N_GENERATIONS = 10
      CELL_DIVISION_TIMES = abs(np.random.gamma(T_GENERATION,1,size=N_GENERATIONS)) 
      smod.DoStochSim(end=CELL_DIVISION_TIMES[0],mode='time',trajectories=1)
      doSequentialSim(smod,N_GENERATIONS,CELL_DIVISION_TIMES)
      smod.PlotSpeciesTimeSeries(species2plot=['mRNA'],title=graphtitle)
      smod.PlotSpeciesTimeSeries(species2plot=['MatureProtein'],title=graphtitle)
    
      print('done')
# Out:
# simulation with kd, k2, k3 = 1 ,  1 ,  0.1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 1 ,  1 ,  0.5
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 1 ,  1 ,  1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 1 ,  10 ,  0.1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 1 ,  10 ,  0.5
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 1 ,  10 ,  1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 1 ,  50 ,  0.1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 1 ,  50 ,  0.5
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 1 ,  50 ,  1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 2.5 ,  1 ,  0.1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 2.5 ,  1 ,  0.5
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 2.5 ,  1 ,  1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 2.5 ,  10 ,  0.1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 2.5 ,  10 ,  0.5
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 2.5 ,  10 ,  1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 2.5 ,  50 ,  0.1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 2.5 ,  50 ,  0.5
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 2.5 ,  50 ,  1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 5 ,  1 ,  0.1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 5 ,  1 ,  0.5
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 5 ,  1 ,  1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 5 ,  10 ,  0.1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 5 ,  10 ,  0.5
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 5 ,  10 ,  1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 5 ,  50 ,  0.1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 5 ,  50 ,  0.5
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done
# simulation with kd, k2, k3 = 5 ,  50 ,  1
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# Parameters are: ['kdimerization', 'kdimerdeg', 'kActivate', 'kreverse', 'kDNAbinding', 'kmRNA_syn', 'kmRNAdeg', 'kProtsyn', 'kProteindeg', 'kProtmat', 'kProtmat_deg']
# done

# %%
### Test a model with a time event
smod.Model('DBD.psc') 
smod.DoStochSim(trajectories=1,end=600,mode='time')
smod.GetRegularGrid()
smod.PlotAverageSpeciesTimeSeries()

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in d:\python\lib\site-packages (4.36.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in d:\python\lib\site-packages (4.36.1)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
pip install --upgrade jupyterthemes
# Out:
# Requirement already up-to-date: jupyterthemes in d:\python\lib\site-packages (0.20.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in d:\python\lib\site-packages (from jupyterthemes) (4.5.0)
# Requirement already satisfied, skipping upgrade: lesscpy>=0.11.2 in d:\python\lib\site-packages (from jupyterthemes) (0.14.0)
# Requirement already satisfied, skipping upgrade: notebook>=5.6.0 in d:\python\lib\site-packages (from jupyterthemes) (6.0.1)
# Requirement already satisfied, skipping upgrade: matplotlib>=1.4.3 in d:\python\lib\site-packages (from jupyterthemes) (3.1.1)
# Requirement already satisfied, skipping upgrade: ipython>=5.4.1 in d:\python\lib\site-packages (from jupyterthemes) (7.8.0)
# Requirement already satisfied, skipping upgrade: traitlets in d:\python\lib\site-packages (from jupyter-core->jupyterthemes) (4.3.3)
# Requirement already satisfied, skipping upgrade: six in d:\python\lib\site-packages (from lesscpy>=0.11.2->jupyterthemes) (1.12.0)
# Requirement already satisfied, skipping upgrade: ply in d:\python\lib\site-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied, skipping upgrade: jupyter-client>=5.3.1 in d:\python\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (5.3.3)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in d:\python\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.8.2)
# Requirement already satisfied, skipping upgrade: tornado>=5.0 in d:\python\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.0.3)
# Requirement already satisfied, skipping upgrade: jinja2 in d:\python\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (2.10.3)
# Requirement already satisfied, skipping upgrade: Send2Trash in d:\python\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied, skipping upgrade: ipython-genutils in d:\python\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied, skipping upgrade: nbformat in d:\python\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (4.4.0)
# Requirement already satisfied, skipping upgrade: prometheus-client in d:\python\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied, skipping upgrade: pyzmq>=17 in d:\python\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (18.1.0)
# Requirement already satisfied, skipping upgrade: nbconvert in d:\python\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (5.6.0)
# Requirement already satisfied, skipping upgrade: ipykernel in d:\python\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (5.1.2)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in d:\python\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in d:\python\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.1.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in d:\python\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.4.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in d:\python\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in d:\python\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.16.5)
# Requirement already satisfied, skipping upgrade: backcall in d:\python\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.0)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in d:\python\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (41.4.0)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in d:\python\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.15.1)
# Requirement already satisfied, skipping upgrade: pickleshare in d:\python\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied, skipping upgrade: pygments in d:\python\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (2.4.2)
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in d:\python\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.4.1)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<2.1.0,>=2.0.0 in d:\python\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (2.0.10)
# Requirement already satisfied, skipping upgrade: decorator in d:\python\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (4.4.0)
# Requirement already satisfied, skipping upgrade: pywin32>=1.0; sys_platform == "win32" in d:\python\lib\site-packages (from jupyter-client>=5.3.1->notebook>=5.6.0->jupyterthemes) (223)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in d:\python\lib\site-packages (from jinja2->notebook>=5.6.0->jupyterthemes) (1.1.1)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in d:\python\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (3.0.2)
# Requirement already satisfied, skipping upgrade: testpath in d:\python\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.4.2)
# Requirement already satisfied, skipping upgrade: bleach in d:\python\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (3.1.0)
# Requirement already satisfied, skipping upgrade: defusedxml in d:\python\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.6.0)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in d:\python\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in d:\python\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (1.4.2)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in d:\python\lib\site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.3)
# Requirement already satisfied, skipping upgrade: parso>=0.5.0 in d:\python\lib\site-packages (from jedi>=0.10->ipython>=5.4.1->jupyterthemes) (0.5.1)
# Requirement already satisfied, skipping upgrade: wcwidth in d:\python\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (0.1.7)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in d:\python\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.6.0->jupyterthemes) (19.2.0)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in d:\python\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.6.0->jupyterthemes) (0.15.4)
# Requirement already satisfied, skipping upgrade: webencodings in d:\python\lib\site-packages (from bleach->nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
username$ jt -t
# Out:
#   File "<ipython-input-65-328b0e39c659>", line 1
#     username$ jt -t
#             ^
# SyntaxError: invalid syntax
